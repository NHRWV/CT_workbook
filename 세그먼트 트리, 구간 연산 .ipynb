# %%
n = int(input())
m = int(input())

inf = int(1e9)
bus = [[inf] * (n+1) for _ in range(n+1)]

for i in range(1, n+1):
    for j in range(1, n+1):
        if i == j:
            bus[i][j] = 0

for i in range(m):
    a, b, c = map(int, input().split())
    bus[a][b] = min(bus[a][b], c)
    

for k in range(1, n+1):
    for i in range(1, n+1):
        for j in range(1, n+1):
            bus[i][j] = min(bus[i][j], bus[i][k] + bus[k][j])
            
            
for i in range(1, n+1):
    for j in range(1, n+1):
        print(0 if bus[i][j] == inf else bus[i][j], end = ' ')
    print()

# %%
n, s = map(int, input().split())
seq = list(map(int, input().split()))


start = 0
end = 0
hab = 0

mini = int(1e9)


while True:
    if hab >= s:
        hab -= seq[start]
        mini = min(mini, end - start)
        start += 1
        
    elif end == n:
        break
        
    else:
        hab += seq[end]
        end += 1
        
        
print(0 if mini == int(1e9) else mini)

# %% [markdown]
# https://www.acmicpc.net/problem/2042

# %%
# 구간 합 구하기

import sys
# input = lambda: sys.stdin.readline().rstrip()

inf = float('inf')

class SegmentTree:
    def __init__(self, data, default=10**15, func=lambda a, b: max(a,b)):
        """initialize the segment tree with data"""
        self._default = default
        self._func = func
        self._len = len(data)
        self._size = _size = 1 << (self._len - 1).bit_length()
 
        self.data = [default] * (2 * _size)
        self.data[_size:_size + self._len] = data
        for i in reversed(range(_size)):
            self.data[i] = func(self.data[i + i], self.data[i + i + 1])
 
    def __delitem__(self, idx):
        self[idx] = self._default
 
    def __getitem__(self, idx):
        return self.data[idx + self._size]
 
    def __setitem__(self, idx, value):
        idx += self._size
        self.data[idx] = value
        idx >>= 1
        while idx:
            self.data[idx] = self._func(self.data[2 * idx], self.data[2 * idx + 1])
            idx >>= 1
 
    def __len__(self):
        return self._len
 
    def query(self, start, stop):
        if start == stop:
            return self.__getitem__(start)
        stop += 1
        start += self._size
        stop += self._size
 
        res = self._default
        while start < stop:
            if start & 1:
                res = self._func(res, self.data[start])
                start += 1
            if stop & 1:
                stop -= 1
                res = self._func(res, self.data[stop])
            start >>= 1
            stop >>= 1
        return res
 
    def __repr__(self):
        return "SegmentTree({0})".format(self.data)
    
    
    
    
n, m, k = map(int, input().split())
lst = [int(input()) for _ in range(n)]

func = lambda a, b: a + b # 최댓값시 max(a, b)
seg = SegmentTree(lst, 0, func = func)

for i in range(m+k):
    a, b, c = map(int, input().split())
    
    if a == 1:
        b -= 1
        seg[b] = c
    
    elif a == 2:
        b -= 1
        c -= 1
        print(seg.query(b, c))

# %% [markdown]
# https://www.acmicpc.net/problem/2357

# %%
### 최솟값과 최댓값


import sys
# input = lambda: sys.stdin.readline().rstrip()

inf = int(1e9)

class SegmentTree:
    def __init__(self, data, default=10**15, func=lambda a, b: max(a,b)):
        """initialize the segment tree with data"""
        self._default = default
        self._func = func
        self._len = len(data)
        self._size = _size = 1 << (self._len - 1).bit_length()
 
        self.data = [default] * (2 * _size)
        self.data[_size:_size + self._len] = data
        
        for i in reversed(range(_size)):
            self.data[i] = func(self.data[i + i], self.data[i + i + 1])
 
    def __delitem__(self, idx):
        self[idx] = self._default
 
    def __getitem__(self, idx):
        return self.data[idx + self._size]
 
    def __setitem__(self, idx, value):
        idx += self._size
        self.data[idx] = value
        idx >>= 1
        
        while idx:
            self.data[idx] = self._func(self.data[2 * idx], self.data[2 * idx + 1])
            idx >>= 1
 
    def __len__(self):
        return self._len
 
    def query(self, start, stop):
        if start == stop:
            return self.__getitem__(start)
        
        stop += 1
        start += self._size
        stop += self._size
 
        res = self._default
        while start < stop:
            if start & 1:
                res = self._func(res, self.data[start])
                start += 1
            if stop & 1:
                stop -= 1
                res = self._func(res, self.data[stop])
            start >>= 1
            stop >>= 1
        return res
 
    def __repr__(self):
        return "SegmentTree({0})".format(self.data)
    
    
    
n, m = map(int, input().split()) 
lst = [int(input()) for _ in range(n)]

maxi = lambda a, b: max(a, b)
mini = lambda a, b: min(a, b)
maxi_seg = SegmentTree(lst, -inf, func = maxi)
mini_seg = SegmentTree(lst, inf, func = mini)


for i in range(m):
    a, b = map(int, input().split())
    
    a -= 1
    b -= 1
    
    print(mini_seg.query(a, b), maxi_seg.query(a, b))
    
# seg.query(구간 시작, 구간 끝)

# %%
10 4
75
30
100
38
50
51
52
20
81
5
1 10
3 5
6 9
8 10

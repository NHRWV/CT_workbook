# %% [markdown]
# https://www.acmicpc.net/problem/5567

# %%
# 결혼식

from collections import deque

n = int(input())
m = int(input())

edge = [[] for _ in range(n+1)]
for i in range(m):
    a, b = map(int, input().split())
    edge[a].append(b)
    edge[b].append(a)
    
queue = deque([1])

visited = [0] * (n+1)

while queue:
    x = queue.popleft()
    
    for i in edge[x]:
        if not visited[i]:
            visited[i] = visited[x] + 1
            queue.append(i)
            
            
print(visited[2:].count(1) + visited[2:].count(2))

# %% [markdown]
# https://www.acmicpc.net/problem/3187

# %%
# 양치기 꿍

from collections import deque

r, c = map(int, input().split())

area = []
for i in range(r):
    area.append(list(map(str, input())))
    
    
dx = [-1, 1, 0, 0]
dy = [0, 0, -1, 1]
visited = [[0] * c for _ in range(r)]

wolf = 0
sheep = 0

def sol(x, y):
    global wolf, sheep
    
    visited[x][y] = 1
    w = 0
    s = 0
    
    if area[x][y] == 'v':
        w += 1
    if area[x][y] == 'k':
        s += 1
    
    queue = deque([(x, y)])
    while queue:
        x, y = queue.popleft()
        
        for i in range(4):
            nx = x + dx[i]
            ny = y + dy[i]
            
            if nx < 0 or nx >= r or ny < 0 or ny >= c:
                continue
            
            if not visited[nx][ny] and area[nx][ny] != '#':
                visited[nx][ny] = 1
                
                if area[nx][ny] == 'v':
                    w += 1
                if area[nx][ny] == 'k':
                    s += 1
                    
                queue.append((nx, ny))
                
    if w < s:
        sheep += s
    else:
        wolf += w
        
        
        
for i in range(r):
    for j in range(c):
        if not visited[i][j] and area[i][j] != '#':
            sol(i, j)
            
            
print(sheep, wolf)

# %% [markdown]
# https://www.acmicpc.net/problem/3184

# %%
from collections import deque

r, c = map(int, input().split())

area = []
for i in range(r):
    area.append(list(map(str, input())))
    
    
dx = [-1, 1, 0, 0]
dy = [0, 0, -1, 1]
visited = [[0] * c for _ in range(r)]

wolf = 0
sheep = 0

def sol(x, y):
    global wolf, sheep
    
    visited[x][y] = 1
    w = 0
    s = 0
    
    if area[x][y] == 'v':
        w += 1
    if area[x][y] == 'o':
        s += 1
    
    queue = deque([(x, y)])
    while queue:
        x, y = queue.popleft()
        
        for i in range(4):
            nx = x + dx[i]
            ny = y + dy[i]
            
            if nx < 0 or nx >= r or ny < 0 or ny >= c:
                continue
            
            if not visited[nx][ny] and area[nx][ny] != '#':
                visited[nx][ny] = 1
                
                if area[nx][ny] == 'v':
                    w += 1
                if area[nx][ny] == 'o':
                    s += 1
                    
                queue.append((nx, ny))
                
    if w < s:
        sheep += s
    else:
        wolf += w
        
        
        
for i in range(r):
    for j in range(c):
        if not visited[i][j] and area[i][j] != '#':
            sol(i, j)
            
            
print(sheep, wolf)

# %% [markdown]
# https://www.acmicpc.net/problem/12761

# %%
# 돌다리

from collections import deque

a, b, n, m = map(int, input().split())

arr = [0] * 100001

queue = deque([n])
while queue:
    x = queue.popleft()
    
    if x == m:
        print(arr[m])
        break
        
    dx = [x-1, x+1, x-a, x+a, x-b, x+b, x*a, x*b]
    
    for i in range(8):
        nx = dx[i]
        
        if nx < 0 or nx >= 100001:
            continue
            
        if arr[nx] == 0:
            arr[nx] = arr[x] + 1
            queue.append(nx)

# %% [markdown]
# https://www.acmicpc.net/problem/14248

# %%
# 점프 점프

from collections import deque

n = int(input())
lst = list(map(int, input().split()))
start = int(input())

def sol(x):
    queue = deque([x])
    visited = [0] * (n+1)
    visited[x] = 1
    answer = 1
    
    while queue:
        x = queue.popleft()
        
        dx = [-lst[x-1], lst[x-1]]
        for i in range(2):
            nx = x + dx[i]
            
            if nx <= 0 or nx > n:
                continue
                
            if not visited[nx]:
                visited[nx] = 1
                queue.append(nx)
                answer += 1
                
                
    return answer


print(sol(start))

# %% [markdown]
# https://www.acmicpc.net/problem/5214

# %%
# 환승

import heapq

n, k, m = map(int, input().split())
    
edge = [[] for _ in range(n+m+1)]
for i in range(m):
    a = list(map(int, input().split()))
    for j in a:
        edge[n+i+1].append((j, 0))
        edge[j].append((n+i+1, 1))
    
    
inf = int(1e9)
answer = -1
def dijk(start):
    global answer
    
    distance = [inf] * (n+m+1)
    queue = []
    
    heapq.heappush(queue, (1, start))
    distance[start] = 1
    
    while queue:
        dist, node = heapq.heappop(queue)
        
        if node == n:
            answer = dist
            break
        
        if distance[node] < dist:
            continue
            
        for nxt, w in edge[node]:
            cost = dist + w
            
            if cost < distance[nxt]:
                distance[nxt] = cost
                heapq.heappush(queue, (cost, nxt))
                


dijk(1)

print(answer)

# %% [markdown]
# https://www.acmicpc.net/problem/1520

# %%
# 내리막 길


m, n = map(int, input().split())

area = []
for i in range(m):
    area.append(list(map(int, input().split())))
    
visited = [[-1] * n for _ in range(m)]

dx = [-1, 1, 0, 0]
dy = [0, 0, -1, 1]
answer = 0

def sol(x, y):
    if x == m-1 and y == n-1:
        return 1
    
    if visited[x][y] != -1:
        return visited[x][y]
    visited[x][y] = 0
    
    for i in range(4):
        nx = x + dx[i]
        ny = y + dy[i]
        
        if nx < 0 or nx >= m or ny < 0 or ny >= n:
            continue
            
        if area[nx][ny] < area[x][y]:
            visited[x][y] += sol(nx, ny)
            
    return visited[x][y]


print(sol(0, 0))

# %% [markdown]
# https://www.acmicpc.net/problem/3055

# %%
# 탈출

from collections import deque

r, c = map(int, input().split())

queue = deque()
visited = [[0] * c for _ in range(r)]

forest = []
for i in range(r):
    a = list(map(str, input().rstrip()))
    forest.append(a)
    
    for j in range(c):
        if a[j] == 'S':
            dochi = (i, j, 1, 0)
            visited[i][j] = 1
            
        elif a[j] == '*':
            queue.append((i, j, 0, 0))
            visited[i][j] = 2
            
queue.insert(0, dochi)

dx = [-1, 1, 0, 0]
dy = [0, 0, -1, 1]
 

def sol():
    while queue:
        x, y, tag, cnt = queue.popleft()
        
        for i in range(4):
            nx = x + dx[i]
            ny = y + dy[i]
            
            if nx < 0 or nx >= r or ny < 0 or ny >= c:
                continue
            
            if tag and forest[nx][ny] == 'D' and visited[x][y] != 2:
                return cnt + 1
            
            if tag:
                if forest[nx][ny] == '.' or forest[nx][ny] == 'D':
                    if not visited[nx][ny]:
                        forest[x][y] = '.'
                        forest[nx][ny] = 'S'
                        visited[nx][ny] = 1
                        queue.append((nx, ny, 1, cnt + 1))
                
            if not tag:
                if forest[nx][ny] != 'X' and forest[nx][ny] != 'D' and visited[nx][ny] != 2:
                    forest[nx][ny] = '*'
                    visited[nx][ny] = 2
                    queue.append((nx, ny, 0, cnt + 1))
                    
    return "KAKTUS"


                
print(sol())
# Out:
# 5 4
# .D.*
# ....
# ..X.
# S.*.
# ....
# 4

# %%
3 3
D.*
...
.S.

3 3
D.*
...
..S

3 6
D...*.
.X.X..
....S.

5 4
.D.*
....
..X.
S.*.
....

# %%
forest
# Out:
# [['D', '*', '*'], ['S', '.', '*'], ['S', '.', 'S']]

# %% [markdown]
# https://www.acmicpc.net/problem/1167

# %%
# 트리의 지름

v = int(input())

edge = [[] for _ in range(v+1)]
for i in range(v):
    a = list(map(int, input().split()))
    edge[a[0]].append(a[1:-1])

# %% [markdown]
# https://www.acmicpc.net/problem/1967

# %%
a = [1,2,3,4,5]

# %%
a[1:-1]
# Out:
# [2, 3, 4]
